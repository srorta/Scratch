# %%
import pandas as pd
import pandas_profiling as pp
import os,glob

# %%
all_files = glob.glob(os.path.join(r"I:\UTCS\Region\SAmerica.Hou\Expl_Proj\South_America\Users\_STS\aGame\ProductionData\AGame_Data_PA\welldowntime","20*.csv"))
for x in all_files: 
    new = x.split("\\")
    welldowntime = pd.read_csv(x)
    prof = pp.ProfileReport(welldowntime)
    prof.to_file(f"I:\\UTCS\\Region\\SAmerica.Hou\\Expl_Proj\\South_America\\Users\\_STS\\aGame\\ProductionData\\AGame_Data_PA\\welldowntime\\{new[-1]}_profile.html")
# Out:
# ...
# Summarize dataset:   0%|          | 0/23 [00:00<?, ?it/s]
# C:\Users\srorta\.conda\envs\pandasprofiling\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Summarize dataset:   0%|          | 0/23 [00:00<?, ?it/s]
# C:\Users\srorta\.conda\envs\pandasprofiling\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
well = pd.read_csv(r"I:\UTCS\Region\SAmerica.Hou\Expl_Proj\South_America\Users\_STS\aGame\srorta\Manipulated_Data\well.csv")
well
# Out:
#           API10ID  MerrickID                             Well_nm  \
# 0      3515322241      27261                         LUDDEN 3-25
# 1      4229533776      47935                   REBA N MILLER 17H
# 2      4236531768      15382                     LAWLESS UNIT #8
# 3      3305306854      49882               HOMER FEDERAL 14X-32F
# 4      1705924842      21306               NEBO OIL CO. F #A-114
# ...           ...        ...                                 ...
# 21660  1705924484      42800  GOODPINE A HOC; WX A2 RF SUN #11-2
# 21661  3509323959      27389                      SCANNELL B 2-3
# 21662  4304740527      42325               RIVERBEND UNIT 27-24E
# 21663  4304736324      12361              HILL CREEK UNIT 08-32F
# 21664  4304731160      12747               RIVERBEND UNIT 03-15E
#
#       CompletionType_nm     Spud_dt GasFirstProduction_dt  \
# 0              GAS WELL  2000-03-27            2002-01-01
# 1              GAS WELL  2012-06-01            2014-05-01
# ...

# %%
well.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21665 entries, 0 to 21664
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   API10ID                21665 non-null  object
#  1   MerrickID              21665 non-null  int64
#  2   Well_nm                21665 non-null  object
#  3   CompletionType_nm      21665 non-null  object
#  4   Spud_dt                21295 non-null  object
#  5   GasFirstProduction_dt  21202 non-null  object
#  6   OilFirstProduction_dt  16806 non-null  object
#  7   SurfaceLatitude_crd    21366 non-null  float64
#  8   SurfaceLongitude_crd   21366 non-null  float64
#  9   StateProvince_nm       21665 non-null  object
#  10  AccountingTeam_nm      21665 non-null  object
#  11  PA_Division_nm         21665 non-null  object
#  12  WellConfig             20652 non-null  object
#  13  TD                     19710 non-null  float64
# ...

# %%
prof = well.profile_report()

# %%
prof.to_file(r"I:\UTCS\Region\SAmerica.Hou\Expl_Proj\South_America\Users\_STS\aGame\srorta\Manipulated_Data\well_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prof
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-20 13:45:22.961181&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import pandas as pd
import requests
import urllib3
from requests.auth import HTTPBasicAuth
from pandas import json_normalize
import os
proxy = "http://hoeprx01.na.xom.com:8080/"

os.environ['http_proxy'] = proxy 
os.environ['HTTP_PROXY'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTPS_PROXY'] = proxy

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
base_url = 'https://wire.subsurface360.xomsvcs.com'
type(base_url)
# Out:
# str

# %%
#Token for Authentication
headers = {"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Imwzc1EtNTBjQ0g0eEJWWkxIVEd3blNSNzY4MCIsImtpZCI6Imwzc1EtNTBjQ0g0eEJWWkxIVEd3blNSNzY4MCJ9.....fj5mSc9lKrhcBLygIrC-X6rvXvWK7HuvNj_nwBcDJ9VgG9yvP8bYUbGQ0NOu1RXjILx2KlOsBy8uprAEHWDOvHRzwxNELMawnTWFgTgdDEK5TOMWzZ9Ccl-569cJLPQq_ZSXcp6yXMVAL2rf2I-YuzLlrRjBMr44HMnIKPQM9FecWky2w5TSXPnmvpafLCRezyDCdmv9YKyu8TLTCmXweHjCu148svLoXzYHxTctCzBnEBo9XwpQYbsnXtMArTYpOHSEVuekdJJjwPl2464ds5-0MlPrpT-VaCSI1_bOfCIr2gpDohvmzCE8Ku282apFZwoxzOhI9uwYOHtYfGabpw"}

# %%
#create requests session
session = requests.Session()
session.headers = headers
session.verify = False

# %%
#Query for all wells with access group
group = 'guyana'
response = session.get(f"{base_url}/api/workflow/v2/wells/{group}/wells")
response.raise_for_status()

# %%
print(response)
# Out:
# <Response [200]>

# %%
#get well data
uwis = response.json()
type(uwis)
print(uwis)
# Out:
# ['NOSPACES5', '100000716831', '100000716831ST1', '100000716831ST2', '100000712627', '100000707025', '100000003478', '100000003489', '100000003480', '100000814795', '100000619819', '100000800998', '100000800998ST01BP00', '100000003488', '100000003476', '100000115939', '100000746755', '100000003423', '21418001260', '21418000661', '21418000510', '21418000650', '2141800144', '2141800142', '2141800135', '2141800143', '2141800148', '2141800149', '2141800137', '2141800139', '2141800138', '2141800133', '2141800141', '2141800146', '2141800145', '21418000411', '2141800147', '2141800136', '2141800140', '100000893167', '222', 'Longtail-3', '21418000422', '21418000710', '21418000700', '21418000450', '21418000791', '21418000680', '21418000751', '21418000752', '21418000642', '21418000631', '21418001080', '21418000640', '2141800076', '21418000630', '21418000790', '21418000520', '21418000660', '21418000750', '21418000570', '21418000580', '21418000560', '21418000590', '21418000600', '21418000610', '21
# ...

# %%
# Data Sections you want to retrieve
typesForRetrieval = 'general,depth,surface_location'

# %%
#for each well, get data
#for help with forming urls, use API
values = []
for uwi in uwis:
    #Get source data
    response = session.get('%s/api/workflow/v2/wells/%s?types=%s&display_units=true' % (base_url,uwi,typesForRetrieval))
    try:
        response.raise_for_status()
    except requests.HTTPError:
        print('Could not load data for %s' % uwi)
        continue
    general = response.json()
    if general is None or 'general' not in general:
        print('No well data for %s' % uwi)
        continue
    else:
        values.append(general)
print(values)
# Out:
# No well data for 222
# ...

# %%
df2 = json_normalize(values, max_level = 5)
df2
# Out:
#     depth.Last_revision_Date  depth.Revision_number depth.business_page  \
# 0           07/08/2020 05:15                      6       well_overview
# 1           07/09/2020 12:06                      2       well_overview
# 2           07/08/2020 20:25                      1       well_overview
# 3           07/09/2020 12:19                      2       well_overview
# 4           07/08/2020 20:35                      1       well_overview
# ..                       ...                    ...                 ...
# 190         09/15/2021 15:53                      2       well_overview
# 191         10/18/2021 15:43                      4       well_overview
# 192         09/21/2021 16:50                      6       well_overview
# 193         02/04/2021 20:39                     26       well_overview
# 194         06/24/2021 14:25                      8       well_overview
#
#      depth.drillFloorElevation depth.drillFloorElevation_uom depth.final  \
# ...

# %%
df2.to_excel(r'H:\WIRE_Headers_general_depth_surfaceloc.xlsx')

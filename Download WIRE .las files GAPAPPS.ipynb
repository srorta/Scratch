# %%
import pandas as pd
import requests
import urllib3
from requests.auth import HTTPBasicAuth
from pandas import json_normalize
import json
import datetime
import os
proxy = "http://hoeprx01.na.xom.com:8080/"

os.environ['http_proxy'] = proxy 
os.environ['HTTP_PROXY'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTPS_PROXY'] = proxy

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
base_url = 'https://wire.subsurface360.xomsvcs.com'
type(base_url)
# Out:
# <class 'str'>

# %%
#Token for Authentication
headers = {"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ik1yNS1BVWliZkJpaTdOZDFqQmViYXhib1hXMCIsImtpZCI6Ik1yNS1BVWliZkJpaTdOZDFqQmViYXhib1hXMCJ9.....w0rT_DyQbIyHQcBuxh54E1nMmXBJeDK0goOdhlPJmmhAGbDAnrgprnYdxGlz1QeeECRGfy6bZC6sUenBJ_L9IcqdnkVJ2mgwfKHar_XTl5vFq-XCwUVze3AtODosblqmOSpXOForDG5kiWHMi7ZzHE8h8fy3rRbyLxYr6bJPgQBhxp4QVqI0ziy4If5pXpJtNjEIBrPx5-2U9f6i9qGf7qlkC0lId2n04y7qlcr2SN1p1CbM6Uw9559eMRm-7vSlq5ppjOpFxbTRaWRV4HfmRHczyUIeTawdREyu8feurWWatflxd2N_rg_3W_jkxmPqFbybALBZKsY7zCCJ6H3Vnw"}

# %%
#create requests session
session = requests.Session()
session.headers = headers
session.verify = False

# %%
#Query for all wells with access group
group = 'guyana'
response = session.get("%s/api/workflow/v2/wells/%s/wells" % (base_url, group))
response.raise_for_status()

# %%
print(response)
# Out:
# <Response [200]>

# %%
#get well data
uwis = response.json()
print(type(uwis))
well4i2 = ['21418000991']
print(type(well4i2))
# Out:
# <class 'list'>
# <class 'list'>

# %%
basefolder = r'D:\geoapps\well4i2'
typesForRetrieval = 'final_general,final_depth,final_surface_location'
deviation = 'final_directional_survey'
deviation_list = []
values = []
none_uwi = []
none_deviation =[]
for uwi in well4i2: 
    response3 = session.get('%s/api/workflow/v2/wells/%s?types=%s&display_units=true' % (base_url,uwi,deviation))
    response2 = session.get('%s/api/workflow/v2/wells/%s?types=%s&display_units=true' % (base_url,uwi,typesForRetrieval))
    response = session.get(f"{base_url}/api/workflow/v2/files/attachments?namespace=FormationEvaluationAndPressureData&uwi={uwi}")
    gapapps = response.json()
    file_pk_list = []
    print(uwi)
    for log in gapapps:
        if log['section_name'] == 'GEOAPPS':
            print(log['file_name'])
            file_pk = log['file_metadata_pk']
            file_pk_list.append(file_pk)
            max_pk = max(file_pk_list)
            print(file_pk_list)            
    for log in gapapps:
        if log['file_metadata_pk'] == max_pk:
            print(log['file_name'])
            print(log['download_url'])
            print(f"{base_url}{log['download_url']}")
            url = f"{base_url}{log['download_url']}"
            download_curve = session.get(url)
            with open(f"{basefolder}\\{log['original_file_name']}", "wb") as file:
                file.write(download_curve.content)
            try:
                response2.raise_for_status()
            except requests.HTTPError:
                print(f"Could not load data for {uwi}")
                continue
            response2Json = response2.json()
            if response2Json is None:
                values.append({})
                none_uwi.append(uwi)
            else:
                values.append(response2Json)
            
            response3Json = response3.json()
            if response3Json is None:
                deviation_list.append({})
                none_deviation.append(uwi)
            else:
                deviation_list.append(response3Json)
                

    file_pk_list.clear()
print(values)
print(none_uwi)
print(deviation_list)
# Out:
# 21418000991
# liz_4i2_bp1_geoapps_2021_11_24_18:59:14.464013.las
# [11173]
# liz_4i2_bp1_geoapps_2021_11_24_18:59:14.464013.las
# /api/filemetadata/downloadfile/well-planning-ui-version-files/liz_4i2_bp1_geoapps_2021_11_24_18:59:14.464013.las
# https://wire.subsurface360.xomsvcs.com/api/filemetadata/downloadfile/well-planning-ui-version-files/liz_4i2_bp1_geoapps_2021_11_24_18:59:14.464013.las
# ...

# %%
wire_metadata_df = json_normalize(values, max_level = 2)
wire_deviation_df = json_normalize(deviation_list)
wire_deviation_df
# Out:
#                  final_directional_survey.Attributes  ... final_directional_survey.wellPathName
# 0  [{'Latitude': '8.109140555555555', 'Longitude'...  ...                          LIZ_4i2 BP01
#
# [1 rows x 13 columns]

# %%
new_wire_dev = wire_deviation_df.dropna(how='all')
new_wire_dev.index.values
new_wire_dev
# Out:
#                  final_directional_survey.Attributes  ... final_directional_survey.wellPathName
# 0  [{'Latitude': '8.109140555555555', 'Longitude'...  ...                          LIZ_4i2 BP01
#
# [1 rows x 13 columns]

# %%
for x in new_wire_dev.index.values:
    json_df1 = pd.json_normalize(wire_deviation_df.iloc[x,0])
    well_name = wire_deviation_df.iloc[x,12]
    json_df1["Well Name"] = well_name
    json_df1.to_excel(fr"D:\Dev_Surv_geo\{well_name}.xlsx")

# %%
wire_metadata_drop = wire_metadata_df.dropna(how='all')
wire_metadata_drop.to_excel(fr"D:\survey\survey_final.xlsx")
